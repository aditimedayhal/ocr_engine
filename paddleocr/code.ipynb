# %%
pip install paddlepaddle
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !paddleocr --image_dir C:\Users\aditi\OneDrive\Pictures\certificate.png --lang=en
# Out:
# [2025/01/09 14:30:49] ppocr INFO: for usage help, please use `paddleocr --help`
# ...

# %%
# %run pdfocr.py
# Out:
# Raw output for page 1:
# [2025/01/10 10:55:38] ppocr INFO: for usage help, please use `paddleocr --help`
# ...

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %run boundingbox.py
# Out:
# Output saved at C:\PES MATERIALS\SimTech internship\output_image.png
